# %% [markdown]
# # Using Machine Learning to Identify Photons

# %% [markdown]
# ## Importing Data

# %%
import uproot
import matplotlib.pyplot as plt
import awkward as ak

# %%
filespath="/data/mhance/photons/NTUP_ZLLG/"
filename = [
'mc16e_13TeV/00-03-01/mc16e.PowhegPythia8EvtGen_AZNLOCTEQ6L1_Zee.DAOD_EGAM3.e3601_e5984_s3126_r10724_r10726_p3954.root',
'mc16e_13TeV/00-03-01/mc16e.PowhegPythia8EvtGen_AZNLOCTEQ6L1_Zmumu.DAOD_EGAM4.e3601_e5984_s3126_r10724_r10726_p3954.root',
'mc16e_13TeV/00-03-01/mc16e.Sh_224_NN30NNLO_eegamma_LO_pty_140_E_CMS.DAOD_EGAM3.e7006_e5984_s3126_r10724_r10726_p3956.root',
'mc16e_13TeV/00-03-01/mc16e.Sh_224_NN30NNLO_eegamma_LO_pty_15_35.DAOD_EGAM3.e7006_e5984_s3126_r10724_r10726_p3956.root',
'mc16e_13TeV/00-03-01/mc16e.Sh_224_NN30NNLO_eegamma_LO_pty_35_70.DAOD_EGAM3.e7006_e5984_s3126_r10724_r10726_p3956.root',
'mc16e_13TeV/00-03-01/mc16e.Sh_224_NN30NNLO_eegamma_LO_pty_70_140.DAOD_EGAM3.e7006_e5984_s3126_r10724_r10726_p3956.root',
'mc16e_13TeV/00-03-01/mc16e.Sh_224_NN30NNLO_eegamma_LO_pty_7_15.DAOD_EGAM3.e7006_e5984_s3126_r10724_r10726_p3956.root',
'mc16e_13TeV/00-03-01/mc16e.Sh_224_NN30NNLO_mumugamma_LO_pty_7_15.DAOD_EGAM4.e7006_e5984_s3126_r10724_r10726_p3956.root',
'mc16e_13TeV/00-03-01/mc16e.Sh_224_NN30NNLO_mumugamma_LO_pty_140_E_CMS.DAOD_EGAM4.e7006_e5984_s3126_r10724_r10726_p3956.root',
'mc16e_13TeV/00-03-01/mc16e.Sh_224_NN30NNLO_mumugamma_LO_pty_15_35.DAOD_EGAM4.e7006_e5984_s3126_r10724_r10726_p3956.root',
'mc16e_13TeV/00-03-01/mc16e.Sh_224_NN30NNLO_mumugamma_LO_pty_35_70.DAOD_EGAM4.e7006_e5984_s3126_r10724_r10726_p3956.root',
'mc16e_13TeV/00-03-01/mc16e.Sh_224_NN30NNLO_mumugamma_LO_pty_70_140.DAOD_EGAM4.e7006_e5984_s3126_r10724_r10726_p3956.root'
]
treename = "output"
full_path = [f"{filespath}{file}" for file in filename]
expressions_for_batch = ['ph.pt','ph.eta','ph.rhad','ph.rhad1','ph.reta','ph.rphi','ph.weta2','ph.eratio','ph.deltae','ph.wstot','ph.fside','ph.w1','ph.truth_pdgId','ph.truth_type','ph.convFlag']
data=[]
for file_path in full_path:
    with uproot.open(file_path) as events:
        data.append(events[treename].arrays(expressions_for_batch))

data = ak.concatenate(data)

# %% [markdown]
# ## Converting Data from Awkward Arrays

# %%
from LearningCutsUtils.ScottsUtils import featSort

data = featSort(data)
# Out:
# .
# .
# ph.pt 969759 <class 'numpy.ndarray'>
# ph.eta 969759 <class 'numpy.ndarray'>
# ph.rhad 969759 <class 'numpy.ndarray'>
# ph.rhad1 969759 <class 'numpy.ndarray'>
# ph.reta 969759 <class 'numpy.ndarray'>
# ph.rphi 969759 <class 'numpy.ndarray'>
# ph.weta2 969759 <class 'numpy.ndarray'>
# ph.eratio 969759 <class 'numpy.ndarray'>
# ph.deltae 969759 <class 'numpy.ndarray'>
# ph.wstot 969759 <class 'numpy.ndarray'>
# ph.fside 969759 <class 'numpy.ndarray'>
# ph.w1 969759 <class 'numpy.ndarray'>
# ph.truth_pdgId 969759 <class 'numpy.ndarray'>
# ph.truth_type 969759 <class 'numpy.ndarray'>
# ph.convFlag 969759 <class 'numpy.ndarray'>

# %%
datalist = ['ph.pt','ph.eta','ph.rhad1','ph.reta','ph.rphi','ph.weta2','ph.eratio','ph.deltae','ph.wstot','ph.fside','ph.w1','ph.truth_pdgId','ph.truth_type','ph.convFlag']

# %%
from LearningCutsUtils.ScottsUtils import plotFeats
plotFeats(data)

# %% [markdown]
# ### Preselection of True Conv Photons

# %%
import torch
import numpy as np
from LearningCutsUtils.ScottsUtils import trueSort
truedata, falsedata = trueSort(data,datalist)
# Out:
# We are working with:
# 468009 Signal Events
# 501750 Backround Events
# Signal:Backround = 0.9327533632286995

# %% [markdown]
# ### Plotting True Vs Untrue Features for Conv

# %%
from LearningCutsUtils.ScottsUtils import plotTVF

plotTVF(truedata,falsedata)

# %% [markdown]
# ### Building Network

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_curve, roc_auc_score

import torch
import torch.nn
import torch.optim
import torch.utils.data

import time
import math

# %%
import importlib
import LearningCutsUtils.LearningCutsUtils
## needed if we change LearningCutsUtils and want to avoid reloading the kernel to see the effects
importlib.reload(LearningCutsUtils.LearningCutsUtils)
import LearningCutsUtils.LearningCutsUtils as LCU
from LearningCutsUtils.LearningCutsUtils import getBack, ListToGraph, OneToOneLinear, EfficiencyScanNetwork
from LearningCutsUtils.LearningCutsUtils import loss_fn
from LearningCutsUtils.LearningCutsUtils import effic_loss_fn
# Out:
# Note: LearningCutsUtils classes and functions should now be imported directly from the LearningCutsUtils module, or from the corresponding submodule, e.g.:
#
# from LearningCutsUtils import OneToOneLinear
#
# or
#
# from LearningCutsUtils.Utils import check_effics
#
# Use of LearningCutsUtils.LearningCutsUtils is deprecated and support will be removed in a future commit.
#
# Note: LearningCutsUtils classes and functions should now be imported directly from the LearningCutsUtils module, or from the corresponding submodule, e.g.:
#
# from LearningCutsUtils import OneToOneLinear
#
# or
#
# from LearningCutsUtils.Utils import check_effics
#
# Use of LearningCutsUtils.LearningCutsUtils is deprecated and support will be removed in a future commit.

# %%
import LearningCutsUtils.ScottsUtils
importlib.reload(LearningCutsUtils.ScottsUtils)
from LearningCutsUtils.ScottsUtils import test_train_split

x_train_tensor, y_train_tensor, x_test_tensor, y_test_tensor = test_train_split(data,datalist,0.25)
# Out:
# /home/scjphill/NN-For-Cuts/LearningCutsUtils/ScottsUtils.py:133: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train_tensor=torch.tensor(y_train,dtype=torch.float)
# /home/scjphill/NN-For-Cuts/LearningCutsUtils/ScottsUtils.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test_tensor=torch.tensor(y_test,dtype=torch.float)

# %%
import importlib
import LearningCutsUtils.LearningCutsUtils
## needed if we change LearningCutsUtils and want to avoid reloading the kernel to see the effects
importlib.reload(LearningCutsUtils.LearningCutsUtils)
import LearningCutsUtils.LearningCutsUtils as LCU
from LearningCutsUtils.LearningCutsUtils import getBack, ListToGraph, OneToOneLinear, EfficiencyScanNetwork
from LearningCutsUtils.LearningCutsUtils import loss_fn
from LearningCutsUtils.LearningCutsUtils import effic_loss_fn
# Out:
# Note: LearningCutsUtils classes and functions should now be imported directly from the LearningCutsUtils module, or from the corresponding submodule, e.g.:
#
# from LearningCutsUtils import OneToOneLinear
#
# or
#
# from LearningCutsUtils.Utils import check_effics
#
# Use of LearningCutsUtils.LearningCutsUtils is deprecated and support will be removed in a future commit.

# %%
N=len(data) # number of points
m=9 # dimensions

# %%
gt=1.
lt=-1.
cuts_gt_lt = [lt, gt, gt, lt, gt, ### change these to correct cuts
              lt, lt, lt, lt] # l g g l g l l l l

# %%
targeteffics=[.2,.4,0.6,0.7,0.8,0.9]

# some hyperparameters
activation_input_scale_factor=15
learning_rate=0.2
batch_size=int(len(y_train_tensor)/1.) # only one batch
epochs=20
alpha=10.   # scaling factor to tune how important hitting the target signal efficiency is
beta=0.1     # scaling factor to tune how important background rejection is
gamma=1e-5  # scaling factor for how aggressively to push the cuts to zero
epsilon=1e-0   # how much to penalize deviations

# %%
torch.manual_seed(123)

net = EfficiencyScanNetwork(m,targeteffics,cuts_gt_lt,activation_input_scale_factor) # will take m inputs, return m*n_eff outputs
torch.save(net.state_dict(), 'net_learningbiases_effictarget_untrained.pth')

optimizer = torch.optim.SGD(net.parameters(), lr=learning_rate)
#optimizer = torch.optim.Adam(net.parameters(), lr=0.1)

# %%
device="cpu"
if torch.cuda.is_available():
    torch.backends.cudnn.deterministic = True
    device="cuda:0"
print(device)
# Out:
# cuda:0

# %%
losses = []
losses_test = []

net.load_state_dict(torch.load('net_learningbiases_effictarget_untrained.pth',weights_only=True))
xy_train = torch.utils.data.TensorDataset(x_train_tensor.float(),y_train_tensor)
loader = torch.utils.data.DataLoader(xy_train, batch_size=batch_size, shuffle=True)
debug=False

for epoch in range(epochs):
    net.train()
    start_time = time.time()
    for x_batch, y_batch in loader:
        y_pred = net(x_batch)
        optimizer.zero_grad()
        loss = effic_loss_fn(y_pred, y_batch, m, net, alpha, beta, gamma, epsilon,debug=debug)
        loss.totalloss().backward()
        optimizer.step()
    losses.append(loss)
    net.eval() # configure the model for evaluation (testing)
    y_pred = net(x_test_tensor)
    test_loss = effic_loss_fn(y_pred, y_test_tensor, m, net, alpha, beta, gamma, epsilon)
    losses_test.append(test_loss)
    end_time=time.time()
    elapsed_time = end_time - start_time
    print(f"Completed epoch {epoch:2d} in {elapsed_time:4.1f}s, Train loss={loss.totalloss().data:4.1e}, Test loss={test_loss.totalloss().data:4.1e}")

torch.save(net.state_dict(), 'net_learningbiases_effictarget_trained.pth')
# Out:
# Completed epoch  0 in 19.3s, Train loss=7.4e+00, Test loss=1.2e+00
# Completed epoch  1 in 19.9s, Train loss=1.2e+00, Test loss=5.5e-01
# Completed epoch  2 in 19.7s, Train loss=5.6e-01, Test loss=3.6e-01
# Completed epoch  3 in 17.5s, Train loss=3.6e-01, Test loss=2.6e-01
# Completed epoch  4 in 16.0s, Train loss=2.7e-01, Test loss=2.1e-01
# Completed epoch  5 in 16.3s, Train loss=2.1e-01, Test loss=1.8e-01
# Completed epoch  6 in 16.1s, Train loss=1.8e-01, Test loss=1.5e-01
# Completed epoch  7 in 17.2s, Train loss=1.6e-01, Test loss=1.4e-01
# Completed epoch  8 in 17.2s, Train loss=1.4e-01, Test loss=1.3e-01
# Completed epoch  9 in 15.3s, Train loss=1.3e-01, Test loss=1.2e-01
# Completed epoch 10 in 16.3s, Train loss=1.2e-01, Test loss=1.1e-01
# Completed epoch 11 in 14.7s, Train loss=1.1e-01, Test loss=1.0e-01
# Completed epoch 12 in 18.8s, Train loss=1.0e-01, Test loss=9.7e-02
# Completed epoch 13 in 17.6s, Train loss=9.8e-02, Test loss=9.2e-02
# Completed epoch 14 in 15.9s, Train loss=9.4e-02, Test loss=8.9e-02
# Completed epoch 15 in 14.4s, Train loss=9.0e-02, Test loss=8.6e-02
# Completed epoch 16 in 14.7s, Train loss=8.7e-02, Test loss=8.3e-02
# Completed epoch 17 in 14.9s, Train loss=8.5e-02, Test loss=8.1e-02
# Completed epoch 18 in 13.9s, Train loss=8.2e-02, Test loss=7.9e-02

# %%
LearningCutsUtils.LearningCutsUtils.plotlosses(losses,losses_test)

# %%
for n in range(len(targeteffics)):
    print(f"Target efficiency: {targeteffics[n]*100}%")
    LearningCutsUtils.LearningCutsUtils.check_effic(x_test_tensor,y_test.numpy(),net.nets[n],True)

# %%
# Distributions of cuts
def plotcuts(net):
    fig = plt.figure(figsize=(20,5))
    fig.tight_layout()
    targeteffics=net.effics
    m=net.features
    
    scaled_cuts=[len(targeteffics)*[0] for i in range(m)]
    for n in range(len(targeteffics)):
        cuts=net.nets[n].get_cuts().detach().numpy()
        for f in range(m):
            cutval=cuts[f]
            scaled_cuts[f][n]=cutval
    for b in range(m):
        ax=fig.add_subplot(2,5,1+b)
        plt.subplots_adjust(hspace=0.6,wspace=0.5)
        ax.plot(targeteffics,scaled_cuts[b])
        ax.set_xlabel(f"Target Efficiency")
        ax.set_ylabel("Cut value")
        ax.set_title(f"Feature {b}")
        ax.set_ylim([-10,10])
plotcuts(net)
